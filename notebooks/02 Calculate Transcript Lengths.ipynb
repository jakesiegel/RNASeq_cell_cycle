# %% [markdown]
# # Notebook 2: finding the transcript lengths
#
# author: jake siegel
#
# date: 11.29.2017
#
# The purpose of this notebook is to figure out how to calculate the transcript length for the RNA Seq data using the .gtf file downloaded for gencode v17 from gencode.  The file is in /data/raw
#
# The gtf is massive... it's 1.03GB.  This may be too big to read in all at once.  It might have to be read in in chunks.
#
# The v17.annotation file contains fewer genes than the RNA-Seq processed dataset (~57,400).

# %%
# %matplotlib inline
import pandas as pd
import time

# data_src = '../data/raw/gencode.v17.annotation.gtf'
data_src = '../data/raw/gencode.v17.chr_patch_hapl_scaff.annotation.gtf'
df = pd.read_csv(data_src, skiprows=5, header=None, usecols=[1,2,3,4,8],sep = '\t')
print df.shape
df.head()
# Out:
# (2823730, 5)
#         1           2      3      4  \
# 0  HAVANA        gene  11869  14412
# 1  HAVANA  transcript  11869  14409
# 2  HAVANA        exon  11869  12227
# 3  HAVANA        exon  12613  12721
# 4  HAVANA        exon  13221  14409
#
#                                                    8
# 0  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 1  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 2  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 3  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 4  gene_id "ENSG00000223972.4"; transcript_id "EN...

# %%
# How many genes are there in this build?
df[8].astype(str).str.split('"', expand=True)[1].unique().shape

# %%
# Can I just use the Ensembl genes? No.
test = df.loc[df[1]=="ENSEMBL"]
test[8].astype(str).str.split('"', expand=True)[1].unique().shape

# %%
df['gene_id']=df[8].astype(str).str.split('"', expand=True)[1]
df['transcript_id']=df[8].astype(str).str.split('"', expand=True)[3]
df.head()
# Out:
#         1           2      3      4  \
# 0  HAVANA        gene  11869  14412
# 1  HAVANA  transcript  11869  14409
# 2  HAVANA        exon  11869  12227
# 3  HAVANA        exon  12613  12721
# 4  HAVANA        exon  13221  14409
#
#                                                    8            gene_id  \
# 0  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 1  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 2  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 3  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 4  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
#
#        transcript_id
# 0  ENSG00000223972.4
# 1  ENST00000456328.2
# 2  ENST00000456328.2
# 3  ENST00000456328.2
# 4  ENST00000456328.2

# %%
df['bp']=df[4]-df[3]+1
df.head()
# Out:
#         1           2      3      4  \
# 0  HAVANA        gene  11869  14412
# 1  HAVANA  transcript  11869  14409
# 2  HAVANA        exon  11869  12227
# 3  HAVANA        exon  12613  12721
# 4  HAVANA        exon  13221  14409
#
#                                                    8            gene_id  \
# 0  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 1  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 2  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 3  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
# 4  gene_id "ENSG00000223972.4"; transcript_id "EN...  ENSG00000223972.4
#
#        transcript_id    bp
# 0  ENSG00000223972.4  2544
# 1  ENST00000456328.2  2541
# 2  ENST00000456328.2   359
# 3  ENST00000456328.2   109
# 4  ENST00000456328.2  1189

# %% [markdown]
# OK, so here is where we need to figure out how to calculate the "right" transcript length for each transcript.
#
# The library prep protocol in the paper is a poly-A-selective protocol, so we need the length of the mature transcript.  That means summing over exons.  Many of the genes in this annotation have multiple entries (for example, see below).
#
# So, my plan is to sum over exons for each transcript_id and then take the maximum (by length) of all of the mature transcript_id's for a given gene_id as the length of that gene.

# %%
df.iloc[:20,:]

# %%
# There is a row that is annotated 'gene' in column 2 that is unique for each gene_id.
# That makes for a convenient hierarchy for keeping track of the calculated transcript lengths.
# I am going to put the calculted mature transcript length for each transcript in the row annoted as "transcript"
# in column 2.
# Then I am going to put the maximum calculated transcript length for a given gene in the row annoted "gene".
print 'number of gene_id:', df['gene_id'].loc[df[2]=='gene'].unique().shape
print 'number of transcript_id:', df['transcript_id'].loc[df[2]=='transcript'].unique().shape
# Out:
# number of gene_id: (62798,)
# number of transcript_id: (211826,)

# %%
# Here is a way to do the summation for a given transcript:
import time

start = time.time()
temp = df['bp'].loc[(df['transcript_id']=='ENST00000515242.2')&(df[2]=='exon')].sum()
end = time.time()
print 'summing over 1 transcript id took:', (end-start),'seconds'
# Out:
# summing over 1 transcript id took: 3.26815080643 seconds

# %% [markdown]
# Yeah, that's going to take 8 days to do it that way.  Need to think of a different option.

# %%
# Here we loop over all unique transcripts and put the calculated length in the row annotated "transcript" in column 2.
df2 = pd.DataFrame()
df2 = df.iloc[:20,:]
df2.shape
start = time.time()
df2.groupby(['gene_id','transcript_id',2])['bp'].sum()
end = time.time()
print 'groupby summation for 4 transcipt ids takes:',(end-start),'seconds'


# for transcript in df['transcript_id'].loc[df[2]!='gene'].unique():
#     df['bp'].loc[(df['transcript_id']==transcript)&(df[2]=='transcript')]=df['bp'].loc[(df['transcript_id']==transcript)&(df[2]=='exon')].sum()

# df.iloc[:20,:]
# Out:
# groupby summation for 4 transcipt ids takes: 0.00754117965698 seconds

# %%
lengths = pd.DataFrame()
lengths = df.groupby(['gene_id','transcript_id',2])['bp'].sum()
lengths = lengths.reset_index()
lengths.head()
# Out:
#               gene_id       transcript_id            2     bp
# 0  ENSG00000000003.10  ENSG00000000003.10         gene  11322
# 1  ENSG00000000003.10   ENST00000373020.4          CDS    735
# 2  ENSG00000000003.10   ENST00000373020.4          UTR   1471
# 3  ENSG00000000003.10   ENST00000373020.4         exon   2206
# 4  ENSG00000000003.10   ENST00000373020.4  start_codon      3

# %% [markdown]
# Now we just need to select the maximum exon length for each gene_id

# %%
transcript_lengths = lengths.loc[lengths[2]=='exon'].groupby('gene_id')['bp'].max().reset_index()
transcript_lengths.head()
# Out:
#               gene_id    bp
# 0  ENSG00000000003.10  2206
# 1   ENSG00000000005.5  1339
# 2   ENSG00000000419.8  1161
# 3   ENSG00000000457.8  3477
# 4  ENSG00000000460.12  4355

# %%
transcript_lengths.shape
# Out:
# (62798, 2)

# %%
transcript_lengths.to_csv('../data/interim/transcipt_lengths.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Final Remarks
#
# It seems this did the trick.  This version of the GENCODE v17 annotation has gene_ids that match the read count data and is contains more genes than the read count file, so hopefully every read gene has a transcript length.
#
# The processed lengths are in the /data/interim folder.
#
# The next step is to go back to the read count data and normalize it to TPM. I probably need to figure out what those spike-in control reads mean.  Bare minimum, I should dump them.  I wonder, though, if people use them as a way to normalize the reads.  That seems silly, but there might be some value in that data that I am overlooking.

# %%
# %matplotlib inline
import pandas as pd
import time

# data_src = '../data/raw/gencode.v17.annotation.gtf'
data_src = '../data/raw/gencode.v17.chr_patch_hapl_scaff.annotation.gtf'
df = pd.read_csv(data_src, skiprows=5, header=None,sep = '\t')
print df.shape
df.head()
# Out:
# (2823730, 9)
#       0       1           2      3      4  5  6  7  \
# 0  chr1  HAVANA        gene  11869  14412  .  +  .
# 1  chr1  HAVANA  transcript  11869  14409  .  +  .
# 2  chr1  HAVANA        exon  11869  12227  .  +  .
# 3  chr1  HAVANA        exon  12613  12721  .  +  .
# 4  chr1  HAVANA        exon  13221  14409  .  +  .
#
#                                                    8
# 0  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 1  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 2  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 3  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 4  gene_id "ENSG00000223972.4"; transcript_id "EN...

# %%
df[8].astype(str).str.split('"', expand=True)
# Out:
#                0                  1                 2                  3   \
# 0        gene_id   ENSG00000223972.4  ; transcript_id   ENSG00000223972.4
# 1        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000456328.2
# 2        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000456328.2
# 3        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000456328.2
# 4        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000456328.2
# 5        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000515242.2
# 6        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000515242.2
# 7        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000515242.2
# 8        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000515242.2
# 9        gene_id   ENSG00000223972.4  ; transcript_id   ENST00000518655.2
# 10       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000518655.2
# 11       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000518655.2
# 12       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000518655.2
# 13       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000518655.2
# 14       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 15       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 16       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 17       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 18       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 19       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 20       gene_id   ENSG00000223972.4  ; transcript_id   ENST00000450305.2
# 21       gene_id   ENSG00000227232.4  ; transcript_id   ENSG00000227232.4
# 22       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 23       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 24       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 25       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 26       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 27       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 28       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# 29       gene_id   ENSG00000227232.4  ; transcript_id   ENST00000438504.2
# ...           ...                ...               ...                ...
# 2823700  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823701  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823702  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823703  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823704  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823705  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823706  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823707  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823708  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823709  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823710  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823711  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823712  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374457.3
# 2823713  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823714  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823715  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823716  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823717  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823718  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823719  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823720  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823721  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823722  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823723  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823724  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823725  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823726  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823727  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823728  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
# 2823729  gene_id   ENSG00000215699.3  ; transcript_id   ENST00000374449.3
#
#                    4               5               6      7             8   \
# 0        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 1        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 2        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 3        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 4        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 5        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 6        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 7        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 8        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 9        ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 10       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 11       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 12       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 13       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 14       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 15       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 16       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 17       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 18       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 19       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 20       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 21       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 22       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 23       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 24       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 25       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 26       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 27       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 28       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# 29       ; gene_type       pseudogene  ; gene_status   KNOWN  ; gene_name
# ...               ...             ...             ...    ...           ...
# 2823700  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823701  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823702  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823703  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823704  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823705  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823706  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823707  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823708  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823709  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823710  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823711  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823712  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823713  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823714  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823715  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823716  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823717  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823718  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823719  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823720  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823721  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823722  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823723  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823724  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823725  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823726  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823727  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823728  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
# 2823729  ; gene_type   protein_coding  ; gene_status   KNOWN  ; gene_name
#
#               9   ...     25    26    27    28    29    30    31    32    33  \
# 0        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 1        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 2        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 3        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 4        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 5        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 6        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 7        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 8        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 9        DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 10       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 11       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 12       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 13       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 14       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 15       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 16       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 17       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 18       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 19       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 20       DDX11L1  ...   None  None  None  None  None  None  None  None  None
# 21        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 22        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 23        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 24        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 25        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 26        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 27        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 28        WASH7P  ...   None  None  None  None  None  None  None  None  None
# 29        WASH7P  ...   None  None  None  None  None  None  None  None  None
# ...          ...  ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2823700   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823701   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823702   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823703   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823704   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823705   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823706   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823707   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823708   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823709   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823710   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823711   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823712   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823713   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823714   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823715   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823716   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823717   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823718   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823719   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823720   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823721   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823722   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823723   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823724   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823725   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823726   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823727   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823728   SRSF10  ...   None  None  None  None  None  None  None  None  None
# 2823729   SRSF10  ...   None  None  None  None  None  None  None  None  None
#
#            34
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# ...       ...
# 2823700  None
# 2823701  None
# 2823702  None
# 2823703  None
# 2823704  None
# 2823705  None
# 2823706  None
# 2823707  None
# 2823708  None
# 2823709  None
# 2823710  None
# 2823711  None
# 2823712  None
# 2823713  None
# 2823714  None
# 2823715  None
# 2823716  None
# 2823717  None
# 2823718  None
# 2823719  None
# 2823720  None
# 2823721  None
# 2823722  None
# 2823723  None
# 2823724  None
# 2823725  None
# 2823726  None
# 2823727  None
# 2823728  None
# 2823729  None
#
# [2823730 rows x 35 columns]
